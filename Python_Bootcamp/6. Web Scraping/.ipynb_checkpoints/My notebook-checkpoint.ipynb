# %%
import requests

# %%
result = requests.get("https://en.wikipedia.org/wiki/Testing_effect")

# %%
type(result)
# Out:
# requests.models.Response

# %%
print(result)
# Out:
# <Response [200]>

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(result.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Testing effect - Wikipedia</title>
# ...

# %%
soup.select('title')
# Out:
# [<title>Testing effect - Wikipedia</title>]

# %%
soup.select('p').pop()
# Out:
# <p>It has been suggested that as most studies on the impact of retrieval practice were conducted in <a class="mw-redirect" href="/wiki/WEIRD" title="WEIRD">WEIRD</a> countries this could cause a bias which should be explored in further studies.<sup class="reference" id="cite_ref-:17_110-1"><a href="#cite_note-:17-110">[110]</a></sup>
# </p>

# %%
soup.select('title')[0].getText()
# Out:
# 'Testing effect - Wikipedia'
