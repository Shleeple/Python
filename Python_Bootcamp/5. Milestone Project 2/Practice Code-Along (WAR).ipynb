# %%
from random import shuffle

# %%
suits = ('Clubs', 'Hearts', 'Spades', 'Diamonds')

ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 
          'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')

values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
          'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Card():
    
    def __init__(self, rank, suit):
        self.rank = rank
        self.suit = suit
        self.value = values[rank]
        
    def __str__(self):
        return f"{self.rank} of {self.suit} "

# %%
class Deck():
    
    def __init__(self):
        self.all_cards = []
    
        for suit in suits:
            for rank in ranks:
                created_card = Card(rank,suit)
                self.all_cards.append(created_card)
                
    def deal_one(self):
        return self.all_cards.pop(0)
    
    def shuffle(self):
        shuffle(self.all_cards)

# %%
class Player():
    
    def __init__(self,name):
        self.name = name
        self.all_cards = []
    
    def remove_one(self):
        return self.all_cards.pop(0)
    
    def add_cards(self,new_cards):
        if type(self.all_cards) == type([]):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)
    
    def __str__(self):
        return f"{self.name} has {len(self.all_cards)} cards "

# %%
# Game Setup
player1 = Player("Juanjo")
player2 = Player("Sophie")

new_deck = Deck()
new_deck.shuffle()

game_on = True

for i in range(26):
    player1.all_cards.append(new_deck.deal_one())
    player2.all_cards.append(new_deck.deal_one())

# %%
# Game Logic
round_num = 0
while game_on:
    
    round_num += 1
    print(f"Round number {round_num}")
    
    if len(player1.all_cards) == 0:
        print(f"{player1.name} is out of cards, winner is {player2.name} ")
        game_on = False
        break
    
    if len(player2.all_cards) == 0:
        print(f"{player2.name} is out of cards, winner is {player1.name} ")
        game_on = False
        break
        
    player1_cards = []
    player2_cards = []
    
    player1_cards.append(player1.remove_one())
    player2_cards.append(player2.remove_one())
    
    at_war = True
    
    while at_war:
    
        if player1_cards[-1].value > player2_cards[-1].value:
            print(f"{player1_cards[-1]}vs {player2_cards[-1]}")
            at_war = False
            player1.add_cards(player1_cards)
            player1.add_cards(player2_cards)
        
        elif player1_cards[-1].value < player2_cards[-1].value:
            print(f"{player1_cards[-1]}vs {player2_cards[-1]}")
            at_war = False
            player2.add_cards(player1_cards)
            player2.add_cards(player2_cards)
        
        else:
            print(f"{player1_cards[-1]}vs {player2_cards[-1]}")
            print("WAR!")
            
            if len(player1.all_cards) < 5:
                print(f"{player1.name} unable to declare war\n{player2.name} wins")
                game_on = False
                break
            
            elif len(player2.all_cards) < 5:
                print(f"{player2.name} unable to declare war\n{player1.name} wins")
                game_on = False
                break
            
            else:
                for i in range(5):
                    player1_cards.append(player1.remove_one())
                    player2_cards.append(player2.remove_one())
# Out:
# Round number 1
# Ace of Clubs vs Two of Diamonds
# Round number 2
# Five of Diamonds vs Two of Clubs
# Round number 3
# Queen of Hearts vs Ace of Hearts
# Round number 4
# King of Diamonds vs Seven of Spades
# Round number 5
# Nine of Spades vs King of Hearts
# Round number 6
# Six of Clubs vs Four of Clubs
# Round number 7
# Three of Clubs vs Queen of Diamonds
# Round number 8
# Queen of Spades vs Seven of Clubs
# Round number 9
# Jack of Clubs vs Ten of Diamonds
# Round number 10
# Eight of Diamonds vs Two of Hearts
# Round number 11
# Four of Diamonds vs Eight of Clubs
# Round number 12
# Three of Diamonds vs Six of Diamonds
# Round number 13
# Queen of Clubs vs Three of Hearts
# Round number 14
# Eight of Spades vs Six of Spades
# Round number 15
# Ten of Hearts vs Seven of Hearts
# Round number 16
# Ten of Spades vs Five of Spades
# Round number 17
# Four of Spades vs Five of Clubs
# Round number 18
# Jack of Diamonds vs King of Clubs
# Round number 19
# Jack of Hearts vs Nine of Diamonds
# Round number 20
# Six of Hearts vs Seven of Diamonds
# Round number 21
# King of Spades vs Five of Hearts
# Round number 22
# Ace of Spades vs Eight of Hearts
# Round number 23
# Ace of Diamonds vs Nine of Hearts
# Round number 24
# Three of Spades vs Four of Hearts
# Round number 25
# Ten of Clubs vs Jack of Spades
# Round number 26
# Two of Spades vs Nine of Clubs
# Round number 27
# Ace of Clubs vs Queen of Hearts
# Round number 28
# Two of Diamonds vs Ace of Hearts
# Round number 29
# Five of Diamonds vs Nine of Spades
# Round number 30
# Two of Clubs vs King of Hearts
# Round number 31
# King of Diamonds vs Three of Clubs
# Round number 32
# Seven of Spades vs Queen of Diamonds
# Round number 33
# Six of Clubs vs Four of Diamonds
# Round number 34
# Four of Clubs vs Eight of Clubs
# Round number 35
# Queen of Spades vs Three of Diamonds
# Round number 36
# Seven of Clubs vs Six of Diamonds
# Round number 37
# Jack of Clubs vs Four of Spades
# Round number 38
# Ten of Diamonds vs Five of Clubs
# Round number 39
# Eight of Diamonds vs Jack of Diamonds
# Round number 40
# Two of Hearts vs King of Clubs
# Round number 41
# Queen of Clubs vs Six of Hearts
# Round number 42
# Three of Hearts vs Seven of Diamonds
# Round number 43
# Eight of Spades vs Three of Spades
# Round number 44
# Six of Spades vs Four of Hearts
# Round number 45
# Ten of Hearts vs Ten of Clubs
# WAR!
# Nine of Diamonds vs Ace of Hearts
# Round number 46
# King of Spades vs Five of Diamonds
# Round number 47
# Five of Hearts vs Nine of Spades
# Round number 48
# Ace of Spades vs Two of Clubs
# Round number 49
# Eight of Hearts vs King of Hearts
# Round number 50
# Ace of Diamonds vs Seven of Spades
# Round number 51
# Nine of Hearts vs Queen of Diamonds
# Round number 52
# Ace of Clubs vs Four of Clubs
# Round number 53
# Queen of Hearts vs Eight of Clubs
# Round number 54
# King of Diamonds vs Eight of Diamonds
# Round number 55
# Three of Clubs vs Jack of Diamonds
# Round number 56
# Six of Clubs vs Two of Hearts
# Round number 57
# Four of Diamonds vs King of Clubs
# Round number 58
# Queen of Spades vs Three of Hearts
# Round number 59
# Three of Diamonds vs Seven of Diamonds
# Round number 60
# Seven of Clubs vs Ten of Hearts
# Round number 61
# Six of Diamonds vs Seven of Hearts
# Round number 62
# Jack of Clubs vs Ten of Spades
# Round number 63
# Four of Spades vs Five of Spades
# Round number 64
# Ten of Diamonds vs Jack of Hearts
# Round number 65
# Five of Clubs vs Nine of Diamonds
# Round number 66
# Queen of Clubs vs Ten of Clubs
# Round number 67
# Six of Hearts vs Jack of Spades
# Round number 68
# Eight of Spades vs Two of Spades
# Round number 69
# Three of Spades vs Nine of Clubs
# Round number 70
# Six of Spades vs Two of Diamonds
# Round number 71
# Four of Hearts vs Ace of Hearts
# Round number 72
# King of Spades vs Five of Hearts
# Round number 73
# Five of Diamonds vs Nine of Spades
# Round number 74
# Ace of Spades vs Eight of Hearts
# Round number 75
# Two of Clubs vs King of Hearts
# Round number 76
# Ace of Diamonds vs Nine of Hearts
# Round number 77
# Seven of Spades vs Queen of Diamonds
# Round number 78
# Ace of Clubs vs Three of Clubs
# Round number 79
# Four of Clubs vs Jack of Diamonds
# Round number 80
# Queen of Hearts vs Four of Diamonds
# Round number 81
# Eight of Clubs vs King of Clubs
# Round number 82
# King of Diamonds vs Three of Diamonds
# Round number 83
# Eight of Diamonds vs Seven of Diamonds
# Round number 84
# Six of Clubs vs Seven of Clubs
# Round number 85
# Two of Hearts vs Ten of Hearts
# Round number 86
# Queen of Spades vs Six of Diamonds
# Round number 87
# Three of Hearts vs Seven of Hearts
# Round number 88
# Jack of Clubs vs Four of Spades
# Round number 89
# Ten of Spades vs Five of Spades
# Round number 90
# Queen of Clubs vs Ten of Diamonds
# Round number 91
# Ten of Clubs vs Jack of Hearts
# Round number 92
# Eight of Spades vs Five of Clubs
# Round number 93
# Two of Spades vs Nine of Diamonds
# Round number 94
# Six of Spades vs Six of Hearts
# WAR!
# Eight of Hearts vs Ace of Hearts
# Round number 95
# Ace of Diamonds vs Five of Diamonds
# Round number 96
# Nine of Hearts vs Nine of Spades
# WAR!
# King of Diamonds vs Four of Clubs
# Round number 97
# Three of Diamonds vs Jack of Diamonds
# Round number 98
# Eight of Diamonds vs Eight of Clubs
# WAR!
# Four of Spades vs Ten of Hearts
# Round number 99
# Ten of Spades vs Three of Hearts
# Round number 100
# Five of Spades vs Seven of Hearts
# Round number 101
# Queen of Clubs vs Ten of Clubs
# Round number 102
# Ten of Diamonds vs Jack of Hearts
# Round number 103
# Eight of Spades vs Two of Spades
# Round number 104
# Five of Clubs vs Nine of Diamonds
# Round number 105
# Ace of Diamonds vs Six of Spades
# Round number 106
# Five of Diamonds vs Two of Diamonds
# Round number 107
# Nine of Hearts vs King of Spades
# Round number 108
# Ace of Clubs vs Five of Hearts
# Round number 109
# Three of Clubs vs Ace of Spades
# Round number 110
# Queen of Hearts vs Eight of Hearts
# Round number 111
# Four of Diamonds vs Six of Hearts
# Round number 112
# King of Diamonds vs Jack of Spades
# Round number 113
# Nine of Spades vs Three of Spades
# Round number 114
# Two of Clubs vs Nine of Clubs
# Round number 115
# King of Hearts vs Four of Hearts
# Round number 116
# Seven of Spades vs Ace of Hearts
# Round number 117
# Queen of Diamonds vs Three of Diamonds
# Round number 118
# Four of Clubs vs Jack of Diamonds
# Round number 119
# Ten of Spades vs Eight of Diamonds
# Round number 120
# Three of Hearts vs Seven of Diamonds
# Round number 121
# Queen of Clubs vs Queen of Spades
# WAR!
# Six of Spades vs King of Clubs
# Round number 122
# Five of Diamonds vs Six of Clubs
# Round number 123
# Two of Diamonds vs Seven of Clubs
# Round number 124
# Ace of Clubs vs Two of Hearts
# Round number 125
# Five of Hearts vs Ten of Hearts
# Round number 126
# Queen of Hearts vs Five of Spades
# Round number 127
# Eight of Hearts vs Seven of Hearts
# Round number 128
# King of Diamonds vs Ten of Diamonds
# Round number 129
# Jack of Spades vs Jack of Hearts
# WAR!
# Queen of Diamonds vs Three of Clubs
# Round number 130
# Three of Diamonds vs Ace of Spades
# Round number 131
# Ten of Spades vs Four of Diamonds
# Round number 132
# Eight of Diamonds vs Six of Hearts
# Round number 133
# Ace of Clubs vs Two of Clubs
# Round number 134
# Two of Hearts vs Nine of Clubs
# Round number 135
# Queen of Hearts vs Seven of Spades
# Round number 136
# Five of Spades vs Ace of Hearts
# Round number 137
# Eight of Hearts vs Four of Clubs
# Round number 138
# Seven of Hearts vs Jack of Diamonds
# Round number 139
# King of Diamonds vs Three of Hearts
# Round number 140
# Ten of Diamonds vs Seven of Diamonds
# Round number 141
# Jack of Spades vs Queen of Clubs
# Round number 142
# Nine of Spades vs Ten of Clubs
# Round number 143
# Three of Spades vs Eight of Spades
# Round number 144
# King of Hearts vs Two of Spades
# Round number 145
# Four of Hearts vs Ace of Diamonds
# Round number 146
# Queen of Diamonds vs Six of Spades
# Round number 147
# Jack of Hearts vs Queen of Spades
# Round number 148
# Five of Clubs vs Six of Diamonds
# Round number 149
# Nine of Diamonds vs Jack of Clubs
# Round number 150
# Nine of Hearts vs Four of Spades
# Round number 151
# King of Spades vs Eight of Clubs
# Round number 152
# Three of Clubs vs King of Clubs
# Round number 153
# Ten of Spades vs Five of Diamonds
# Round number 154
# Four of Diamonds vs Six of Clubs
# Round number 155
# Eight of Diamonds vs Two of Diamonds
# Round number 156
# Six of Hearts vs Seven of Clubs
# Round number 157
# Ace of Clubs vs Five of Hearts
# Round number 158
# Two of Clubs vs Ten of Hearts
# Round number 159
# Queen of Hearts vs Three of Diamonds
# Round number 160
# Seven of Spades vs Ace of Spades
# Round number 161
# Eight of Hearts vs Two of Hearts
# Round number 162
# Four of Clubs vs Nine of Clubs
# Round number 163
# King of Diamonds vs Five of Spades
# Round number 164
# Three of Hearts vs Ace of Hearts
# Round number 165
# Ten of Diamonds vs Seven of Hearts
# Round number 166
# Seven of Diamonds vs Jack of Diamonds
# Round number 167
# King of Hearts vs Jack of Spades
# Round number 168
# Two of Spades vs Queen of Clubs
# Round number 169
# Queen of Diamonds vs Nine of Spades
# Round number 170
# Six of Spades vs Ten of Clubs
# Round number 171
# Nine of Hearts vs Three of Spades
# Round number 172
# Four of Spades vs Eight of Spades
# Round number 173
# King of Spades vs Four of Hearts
# Round number 174
# Eight of Clubs vs Ace of Diamonds
# Round number 175
# Ten of Spades vs Jack of Hearts
# Round number 176
# Five of Diamonds vs Queen of Spades
# Round number 177
# Eight of Diamonds vs Five of Clubs
# Round number 178
# Two of Diamonds vs Six of Diamonds
# Round number 179
# Ace of Clubs vs Nine of Diamonds
# Round number 180
# Five of Hearts vs Jack of Clubs
# Round number 181
# Queen of Hearts vs Three of Clubs
# Round number 182
# Three of Diamonds vs King of Clubs
# Round number 183
# Eight of Hearts vs Four of Diamonds
# Round number 184
# Two of Hearts vs Six of Clubs
# Round number 185
# King of Diamonds vs Six of Hearts
# Round number 186
# Five of Spades vs Seven of Clubs
# Round number 187
# Ten of Diamonds vs Two of Clubs
# Round number 188
# Seven of Hearts vs Ten of Hearts
# Round number 189
# King of Hearts vs Seven of Spades
# Round number 190
# Jack of Spades vs Ace of Spades
# Round number 191
# Queen of Diamonds vs Four of Clubs
# Round number 192
# Nine of Spades vs Nine of Clubs
# WAR!
# Eight of Diamonds vs Two of Spades
# Round number 193
# Five of Clubs vs Queen of Clubs
# Round number 194
# Ace of Clubs vs Six of Spades
# Round number 195
# Nine of Diamonds vs Ten of Clubs
# Round number 196
# Queen of Hearts vs Four of Spades
# Round number 197
# Three of Clubs vs Eight of Spades
# Round number 198
# Eight of Hearts vs Eight of Clubs
# WAR!
# Two of Clubs vs Queen of Spades
# Round number 199
# King of Hearts vs Two of Diamonds
# Round number 200
# Seven of Spades vs Six of Diamonds
# Round number 201
# Queen of Diamonds vs Five of Hearts
# Round number 202
# Four of Clubs vs Jack of Clubs
# Round number 203
# Nine of Spades vs Three of Diamonds
# Round number 204
# Nine of Hearts vs King of Clubs
# Round number 205
# Three of Spades vs Two of Hearts
# Round number 206
# King of Spades vs Six of Clubs
# Round number 207
# Four of Hearts vs Five of Spades
# Round number 208
# Eight of Diamonds vs Seven of Clubs
# Round number 209
# Nine of Clubs vs Seven of Hearts
# Round number 210
# Three of Hearts vs Ten of Hearts
# Round number 211
# Ace of Hearts vs Jack of Spades
# Round number 212
# Seven of Diamonds vs Ace of Spades
# Round number 213
# Jack of Diamonds vs Five of Clubs
# Round number 214
# Two of Spades vs Queen of Clubs
# Round number 215
# Ace of Clubs vs Nine of Diamonds
# Round number 216
# Six of Spades vs Ten of Clubs
# Round number 217
# Queen of Hearts vs Three of Clubs
# Round number 218
# Four of Spades vs Eight of Spades
# Round number 219
# King of Hearts vs Eight of Hearts
# Round number 220
# Two of Diamonds vs Four of Diamonds
# Round number 221
# Seven of Spades vs King of Diamonds
# Round number 222
# Six of Diamonds vs Six of Hearts
# WAR!
# Three of Spades vs Ten of Spades
# Round number 223
# Two of Hearts vs Jack of Hearts
# Round number 224
# King of Spades vs Five of Diamonds
# Round number 225
# Six of Clubs vs Queen of Spades
# Round number 226
# Eight of Diamonds vs Four of Clubs
# Round number 227
# Seven of Clubs vs Jack of Clubs
# Round number 228
# Nine of Clubs vs Nine of Hearts
# WAR!
# Five of Clubs vs Ten of Hearts
# Round number 229
# Ace of Clubs vs Seven of Diamonds
# Round number 230
# Nine of Diamonds vs Ace of Spades
# Round number 231
# Queen of Hearts vs Two of Spades
# Round number 232
# Three of Clubs vs Queen of Clubs
# Round number 233
# King of Hearts vs Six of Spades
# Round number 234
# Eight of Hearts vs Ten of Clubs
# Round number 235
# King of Spades vs Four of Spades
# Round number 236
# Five of Diamonds vs Eight of Spades
# Round number 237
# Eight of Diamonds vs Two of Diamonds
# Round number 238
# Four of Clubs vs Four of Diamonds
# WAR!
# King of Hearts vs Five of Hearts
# Round number 239
# Six of Spades vs Nine of Spades
# Round number 240
# King of Spades vs Three of Diamonds
# Round number 241
# Four of Spades vs Three of Spades
# Round number 242
# Eight of Diamonds vs Six of Hearts
# Round number 243
# Two of Diamonds vs Ten of Diamonds
# Round number 244
# Four of Clubs vs Two of Clubs
# Round number 245
# Ace of Clubs vs Eight of Clubs
# Round number 246
# Seven of Diamonds vs Ace of Diamonds
# Round number 247
# Queen of Hearts vs Ten of Spades
# Round number 248
# Two of Spades vs Two of Hearts
# WAR!
# Six of Diamonds vs Jack of Clubs
# Round number 249
# Queen of Diamonds vs Nine of Clubs
# Round number 250
# Five of Hearts vs Seven of Hearts
# Round number 251
# King of Spades vs Ace of Hearts
# Round number 252
# Three of Diamonds vs Jack of Spades
# Round number 253
# Four of Spades vs Jack of Diamonds
# Round number 254
# Three of Spades vs Five of Clubs
# Round number 255
# Eight of Diamonds vs Nine of Hearts
# Round number 256
# Six of Hearts vs King of Clubs
# Round number 257
# Four of Clubs vs Four of Hearts
# WAR!
# Ten of Spades vs Ace of Spades
# Round number 258
# Queen of Diamonds vs Three of Clubs
# Round number 259
# Nine of Clubs vs Queen of Clubs
# Round number 260
# Queen of Diamonds vs Eight of Hearts
# Round number 261
# Three of Clubs vs Ten of Clubs
# Round number 262
# Queen of Diamonds vs Five of Diamonds
# Round number 263
# Eight of Hearts vs Eight of Spades
# WAR!
# Juanjo unable to declare war
# Sophie wins
